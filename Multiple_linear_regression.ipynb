# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("Student_Performance.csv")
data.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
data.shape
# Out:
# (10000, 6)

# %%
#drop unneccesary columns
data.drop(columns=["Extracurricular Activities" , "Sleep Hours"] , inplace=True)

# %%
data.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
data.describe()
# Out:
#        Hours Studied  Previous Scores  Sample Question Papers Practiced  \
# count   10000.000000     10000.000000                      10000.000000
# mean        4.992900        69.445700                          4.583300
# std         2.589309        17.343152                          2.867348
# min         1.000000        40.000000                          0.000000
# 25%         3.000000        54.000000                          2.000000
# 50%         5.000000        69.000000                          5.000000
# 75%         7.000000        85.000000                          7.000000
# max         9.000000        99.000000                          9.000000
#
#        Performance Index
# count       10000.000000
# mean           55.224800
# std            19.212558
# min            10.000000
# 25%            40.000000
# 50%            55.000000
# 75%            71.000000
# max           100.000000

# %%
x = data.iloc[:,:-1]
y = data["Performance Index"]

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.25 , random_state=42)

# %%
lr = LinearRegression()
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test , y_test)*100
# Out:
# 98.69050029612731

# %%
lr.predict(x_test)
# Out:
# array([54.32864735, 23.50872514, 47.40057681, ..., 67.66793395,
#        54.70939388, 55.78954526])

# %%
y_test
# Out:
# 6252    51.0
# 4684    20.0
# 1731    46.0
# 4742    28.0
# 4521    41.0
#         ...
# 4862    83.0
# 7025    31.0
# 7647    70.0
# 7161    56.0
# 73      52.0
# Name: Performance Index, Length: 2500, dtype: float64

# %% [markdown]
# Mathematical representation of multiple linear regression using this eq --> y = m1x1 + m2x2 +.....+c

# %% [markdown]
# y is our output data and x is the input data (entered by a user)

# %%
m = lr.coef_  #angle (thita) between x and slop

# %%
c = lr.intercept_

# %%
m , c
# Out:
# (array([2.85909435, 1.01662645, 0.18996153]), np.float64(-30.493972528921795))

# %%
y_pred = 2.85909435*x_test["Hours Studied"]+1.01662645*x_test["Previous Scores"]+0.18996153*x_test["Sample Question Papers Practiced"]+(-30.493972528921795)
y_pred
# Out:
# 6252    54.328647
# 4684    23.508725
# 1731    47.400577
# 4742    30.308712
# 4521    44.540659
#           ...
# 4862    82.983326
# 7025    32.535220
# 7647    67.667934
# 7161    54.709394
# 73      55.789545
# Length: 2500, dtype: float64

# %% [markdown]
# Answer of the above mathematical representation and the prediction using multiple linear regression is same it means the algorinthm MLR used is y=m1x1+m2x2 +....+c
