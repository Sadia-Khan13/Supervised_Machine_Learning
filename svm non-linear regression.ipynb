# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

# %%
data = pd.read_csv("Position_Salaries.csv")
data.head(5)
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %%
plt.figure(figsize=(5 , 4))
plt.title("Level VS Salary")
sns.scatterplot(x="Level" , y="Salary" , data=data)
plt.show()

# %%
x = data[["Level"]]
y = data["Salary"]

# %%
from sklearn.preprocessing import PolynomialFeatures
pf =  PolynomialFeatures(degree = 2)
pf.fit(x)
x = pf.transform(x)

# %%
x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=8)

# %%
svr=SVR(kernel = "rbf")
svr.fit(x_train , y_train)
# Out:
# SVR()

# %%
svr.score(x_train , y_train)*100 , svr.score(x_test , y_test)*100
# Out:
# (-18.18322128709251, -288.9929440563509)

# %%
for i in range(1,50):
    x_train , x_test , y_train , y_test = train_test_split(x , y , test_size=0.2 , random_state=i)
    svr=SVR(kernel = "rbf")
    svr.fit(x_train , y_train)
    print(i , svr.score(x_train , y_train)*100 , svr.score(x_test , y_test)*100)
# Out:
# 1 -11.597894025301493 -72.43013883931147
# 2 -14.90722054327549 -1002.7287040815928
# 3 -20.177547693684406 -24.99175041999844
# 4 -13.396868753943792 -58.04730763624082
# 5 -23.696932370314983 -127.55559715195383
# 6 -14.546664746394434 -41.52835946628946
# 7 -20.125891188375423 -172.7294424002716
# 8 -18.18322128709251 -288.9929440563509
# 9 -16.101844520972474 -94.93416281491551
# 10 -14.151550126696733 -46.48508700688871
# 11 -14.968954646297504 -930.2338849369479
# 12 -20.125891188375423 -172.7294424002716
# 13 -17.302645489983615 -130.599316404346
# 14 -10.19065713243361 -79.44156399152386
# 15 -23.451184090979083 0.004881133221823486
# 16 -23.451184090979083 0.004881133221823486
# 17 -19.57163287363606 -17.356931760104644
# 18 -14.72385575664672 -251.447096081196
# 19 -20.041981391867083 -12.955991595539128
# 20 -20.041981391867104 -12.955991595539128
# 21 -17.03232379315869 -57597.88169117841
# 22 -17.03232379315869 -57597.88169117841
# 23 -20.125891188375398 -172.7294424002716
# 24 -15.245790283616856 -97.76442648075093
# 25 -18.654841323623028 -120.99003248890887
# 26 -16.101844520972474 -94.93416281491551
# 27 -14.496589356810352 -1295.9332914141528
# 28 -11.59789402530147 -72.43013883931147
# 29 -18.183221287092486 -288.9929440563509
# 30 -17.73932367496178 -260091.72086907152
# 31 -14.907220543275512 -1002.7287040815928
# 32 -12.376745480736528 -69.15149717205531
# 33 -13.396868753943792 -58.04730763624082
# 34 -12.787299753008874 -67.56580520966766
# 35 -23.451184090979105 0.004881133221823486
# 36 -10.19065713243359 -79.44156399152386
# 37 -15.245790283616856 -97.76442648075093
# 38 -14.74890814583365 -39.23189484360805
# 39 -17.03232379315869 -57597.88169117841
# 40 -13.713311855107936 -2844.2892008455597
# 41 -30.292554765029212 -1023.9404848894089
# 42 -14.546664746394434 -41.52835946628946
# 43 -10.19065713243361 -79.44156399152386
# 44 -19.571632873636034 -17.356931760104644
# 45 -14.496589356810352 -1295.9332914141528
# 46 -20.28261208248456 -11.107199642777598
# 47 -17.03232379315869 -57597.88169117841
# 48 -25.998153299833216 -300.42963072800546
# 49 -12.787299753008874 -67.56580520966766
